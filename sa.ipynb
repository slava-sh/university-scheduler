# %%
# %matplotlib inline
import pandas as pd

# %%
sa = pd.read_csv('sa.csv', header=None, names=['Progress', 'Temp', 'Delta', 'Prob'])
sa
# Out:
#        Progress    Temp  Delta    Prob
# 0        0.0002  9.9837     88  0.0001
# 1        0.0002  9.9774     18  0.1414
# 2        0.0003  9.9761     18  0.1413
# 3        0.0003  9.9747     18  0.1413
# 4        0.0003  9.9734      5  0.3772
# 5        0.0003  9.9722     49  0.0073
# 6        0.0003  9.9710     10  0.2684
# 7        0.0003  9.9696      3  0.4253
# 8        0.0004  9.9670     25  0.0753
# 9        0.0004  9.9657     18  0.1411
# 10       0.0004  9.9645     12  0.2307
# 11       0.0004  9.9631     18  0.1410
# 12       0.0004  9.9619      5  0.3771
# 13       0.0004  9.9606     23  0.0904
# 14       0.0004  9.9594     18  0.1410
# 15       0.0005  9.9581     49  0.0072
# 16       0.0005  9.9568     18  0.1409
# 17       0.0005  9.9555     36  0.0262
# 18       0.0005  9.9543      9  0.2882
# 19       0.0005  9.9530     31  0.0425
# 20       0.0006  9.9492     18  0.1407
# 21       0.0006  9.9479      7  0.3310
# 22       0.0006  9.9444     11  0.2486
# ...

# %%
sa.plot('Progress', 'Temp', figsize=(16, 5))

# %%
s = sa[sa.Progress > 0.3].sample(10000).sort_index()
s.plot.scatter('Progress', 'Delta', marker='.', figsize=(16, 5))

# %%
s.plot('Progress', 'Prob', marker='.', figsize=(16, 5))
