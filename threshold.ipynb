# %%
# %matplotlib inline
import pandas as pd

# %%
data = pd.read_csv('sa.csv', header=None, names=['Progress', 'TP', 'Delta', 'F'])
data
# Out:
#        Progress    TP  Delta      F
# 0        0.0002  0.00     -4  28673
# 1        0.0002  0.00     59  28669
# 2        0.0002  0.01      5  28669
# 3        0.0002  0.02     -6  28669
# 4        0.0003  0.00      9  28663
# 5        0.0003  0.01     18  28663
# 6        0.0003  0.02    -25  28663
# 7        0.0003  0.00     18  28638
# 8        0.0003  0.01     81  28638
# 9        0.0003  0.02     37  28638
# 10       0.0003  0.03     -6  28638
# 11       0.0004  0.00     18  28632
# 12       0.0004  0.01     18  28632
# 13       0.0004  0.02    -41  28632
# 14       0.0004  0.00     87  28591
# 15       0.0004  0.01    -47  28591
# 16       0.0004  0.00      9  28544
# 17       0.0005  0.01    -27  28544
# 18       0.0005  0.00     38  28517
# 19       0.0005  0.01    -12  28517
# 20       0.0005  0.00    -23  28505
# 21       0.0005  0.00     12  28482
# 22       0.0005  0.01      2  28482
# 23       0.0005  0.02     18  28482
# 24       0.0006  0.03     -2  28482
# ...

# %%
data.plot('Progress', 'TP', figsize=(16, 5), logy=True)

# %%
s = data[data.Progress > 0.3]
s.plot.scatter('Progress', 'Delta', marker='.', figsize=(16, 5))
s.plot('Progress', 'TP', figsize=(16, 5))
s.plot('Progress', 'F', figsize=(16, 5))

# %%
data.describe()
# Out:
#            Progress            TP         Delta             F
# count  97004.000000  97004.000000  97004.000000  97004.000000
# mean       0.506646      0.774885     42.083017  18235.498083
# std        0.286959      0.733959     25.358069   1233.568692
# min        0.000200      0.000000    -90.000000  17670.000000
# 25%        0.260300      0.190000     23.000000  17713.000000
# 50%        0.506300      0.550000     39.000000  17834.000000
# 75%        0.755800      1.170000     58.000000  18147.000000
# max        1.000000      4.490000    144.000000  28673.000000
