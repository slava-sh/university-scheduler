# %%
# %matplotlib inline
import pandas as pd

# %%
data = pd.read_csv('bf.csv', header=None, names=['Progress', 'Delta', 'F'])
data
# Out:
#        Progress  Delta      F
# 0        0.0002    -23  29065
# 1        0.0002     18  29042
# 2        0.0003    -43  29042
# 3        0.0003     18  28999
# 4        0.0003    -31  28999
# 5        0.0003     64  28968
# 6        0.0003     74  28968
# 7        0.0004    -12  28968
# 8        0.0004     18  28956
# 9        0.0004     54  28956
# 10       0.0004      3  28956
# 11       0.0004      9  28956
# 12       0.0004    -19  28956
# 13       0.0005     29  28937
# 14       0.0005      2  28937
# 15       0.0005     41  28937
# 16       0.0005      7  28937
# 17       0.0005     48  28937
# 18       0.0005      2  28937
# 19       0.0005      2  28937
# 20       0.0006    -55  28937
# 21       0.0006    -26  28882
# 22       0.0006     18  28856
# 23       0.0006      5  28856
# 24       0.0006     -4  28856
# 25       0.0006     18  28852
# 26       0.0006     42  28852
# 27       0.0007     11  28852
# 28       0.0007     18  28852
# 29       0.0007      2  28852
# ...

# %%
s = data[data.Progress > 0.2]
s.plot.scatter('Progress', 'Delta', marker='.', figsize=(16, 5))

# %%
s.plot('Progress', 'F', figsize=(16, 5), logy=True)

# %%
data.describe()
# Out:
#            Progress         Delta             F
# count  97875.000000  97875.000000  97875.000000
# mean       0.508604     42.395586  18346.530891
# std        0.286211     25.553115   1256.914742
# min        0.000200    -74.000000  17691.000000
# 25%        0.263050     24.000000  17741.000000
# 50%        0.510400     39.000000  17919.000000
# 75%        0.756700     59.000000  18355.000000
# max        1.000000    144.000000  29065.000000
